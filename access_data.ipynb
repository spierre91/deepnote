# %%
from sklearn import datasets

# %%
digits = datasets.load_digits()

# %%
import matplotlib.pyplot as plt
plt.gray()
plt.matshow(digits.images[0])

# %%
import matplotlib.pyplot as plt

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)
ax1.imshow(digits.images[0], cmap=plt.get_cmap('gray'))
ax1.set_title(str(digits.target_names[0]))
ax2.imshow(digits.images[1], cmap=plt.get_cmap('gray'))
ax2.set_title(str(digits.target_names[1]))
ax3.imshow(digits.images[2], cmap=plt.get_cmap('gray'))
ax3.set_title(str(digits.target_names[2]))

fig.show()

# %%
print(len(digits.target))
# Out:
# 1797

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
iris_data = load_iris()

# %%
iris_features = iris_data.data[: , [0,1,2,3]]
iris_features_all = [x[2] for x in iris_features]
iris_targets = [x[3] for x in iris_features]

# %%
print(len(iris_features_all))
# Out:
# 150

# %%
import seaborn as sns
sns.set()
iris_categories = ('Iris-setosa','Iris-versicolor','Iris-virginica')
iris_categories_colors = ['red', 'yellow', 'black']
iris_dataset = ((iris_features_all[:50], iris_targets[:50]), (iris_features_all[50:100], iris_targets[50:100]), 
        (iris_features_all[100:150], iris_targets[100:150]))
print(zip(data,iris_categories_colors,iris_categories))

for data, color, category in zip(iris_dataset,iris_categories_colors,iris_categories):
    X, y = data
    plt.scatter(X, y, c=color, alpha=1)


plt.xlabel('Iris Petal length')
plt.ylabel('Iris Petal width')
plt.show()

# %%
from sklearn.datasets import load_diabetes
diabetes_data = load_diabetes(as_frame=True)

# %%
features = diabetes_data['feature_names']
features.remove('sex')

fig, axs = plt.subplots(3, 3)
fig.suptitle('Diabetes Data')
for i in range(3):
    for j in range(3):
        n = j + i * 3
        feature = features[n]
        axs[i, j].scatter(diabetes_data['data'][feature], diabetes_data['target'], s=2)
        axs[i, j].set_xlabel(feature)
        axs[i, j].set_ylabel('Target')
plt.tight_layout()
plt.show()

# %%
from tensorflow import keras
# Out:
# 2022-11-21 17:59:09.856310: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-21 17:59:10.021228: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-11-21 17:59:10.021283: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-11-21 17:59:10.063176: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
fashion_data = keras.datasets.fashion_mnist.load_data()

# %%
(X_train, y_train), (X_test, y_test) = fashion_data

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)
ax1.imshow(X_train[0],)
ax1.set_title(str(y_train[0]))
ax2.imshow(X_train[1],)
ax2.set_title(str(y_train[1]))
ax3.imshow(X_train[2],)
ax3.set_title(str(y_train[2]))
# Out:
# '\nax2.imshow(fashion_data.images[1], )\nax2.set_title(str(fashion_data.target_names[1]))\nax3.imshow(fashion_data.images[2],)\nax3.set_title(str(fashion_data.target_names[2]))\n'

# %%
cifar = keras.datasets.cifar100.load_data(label_mode="fine")
# Out:
# ...
# 169001437/169001437 [==============================] - 2s 0us/step

# %%
(X_train, y_train), (X_test, y_test) = cifar

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3)
ax1.imshow(X_train[0],)
ax1.set_title(str(y_train[0]))
ax2.imshow(X_train[1],)
ax2.set_title(str(y_train[1]))
ax3.imshow(X_train[2],)
ax3.set_title(str(y_train[2]))
# Out:
# Text(0.5, 1.0, '[0]')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8f38039a-ca54-42b1-b9f0-fbf17112e2a8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
