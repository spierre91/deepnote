# %%
import pandas as pd 

df = pd.read_csv("insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import numpy as np 
def log_transform(input_list):
    return np.log(input_list)

# %%
bmi_list = list(df['bmi'])
bmi_lt_map = list(map(log_transform, bmi_list))
df['bmi_lt_map'] = bmi_lt_map

# %%
df['bmi_lt_listcomp'] = [np.log(bmi) for bmi in list(df['bmi'])]

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  bmi_lt_map  \
# 0   19  female  27.900         0    yes  southwest  16884.92400    3.328627
# 1   18    male  33.770         1     no  southeast   1725.55230    3.519573
# 2   28    male  33.000         3     no  southeast   4449.46200    3.496508
# 3   33    male  22.705         0     no  northwest  21984.47061    3.122585
# 4   32    male  28.880         0     no  northwest   3866.85520    3.363149
#
#    bmi_lt_listcomp
# 0         3.328627
# 1         3.519573
# 2         3.496508
# 3         3.122585
# 4         3.363149

# %%
df['bmi_lt_direct'] = np.log(df['bmi'])

# %%
my_predictions = [[0.5, 0.2, 0.8], [0.3, 0.1, 0.9], [1.0, 0.2, 0.7]]

# %%
flattened_predictions = [prob for row in my_predictions for prob in row]
print(flattened_predictions)
# Out:
# [0.5, 0.2, 0.8, 0.3, 0.1, 0.9, 1.0, 0.2, 0.7]

# %%
flat_fl = []
for row in my_predictions:
    for prob in row:
        flat_fl.append(prob)
print(flat_fl)
# Out:
# [0.5, 0.2, 0.8, 0.3, 0.1, 0.9, 1.0, 0.2, 0.7]

# %%
ml_labels = [['Yes' if prob >= 0.8  else 'Maybe' if (prob > 0.5 and prob < 0.8) else 'No' for prob in row] for row in my_predictions]
print(my_predictions)
print(ml_labels)
# Out:
# [[0.5, 0.2, 0.8], [0.3, 0.1, 0.9], [1.0, 0.2, 0.7]]
# [['No', 'No', 'Yes'], ['No', 'No', 'Yes'], ['Yes', 'No', 'Maybe']]

# %%
fl_labels = []

for row in my_predictions:
    hold_list = []
    for prob in row:
        if prob >= 0.8:
            hold_list.append('Yes')
        elif (prob > 0.5 and prob < 0.8):
            hold_list.append('Maybe')
        else:
            hold_list.append('No')
    fl_labels.append(hold_list)

print(my_predictions)
print(fl_labels)
# Out:
# [[0.5, 0.2, 0.8], [0.3, 0.1, 0.9], [1.0, 0.2, 0.7]]
# [['No', 'No', 'Yes'], ['No', 'No', 'Yes'], ['Yes', 'No', 'Maybe']]

# %%
import numpy as np 
mu, sigma = 0.5, 0.1
np.random.seed(42)
probs = np.random.normal(mu, sigma, 100000000)
print(probs[:10])
# Out:
# [0.54967142 0.48617357 0.56476885 0.65230299 0.47658466 0.4765863
#  0.65792128 0.57674347 0.45305256 0.554256  ]

# %%
prob_labels = ['Yes' if prob > 0.5 else 'No' for prob in probs]

# %%
print(prob_labels[:10])
# Out:
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes']

# %%
prob_generator = ('Yes' if prob > 0.5 else 'No' for prob in probs)
probs_sublist = []
for i in range(0, 11):
    probs_sublist.append(next(prob_generator))
print(probs_sublist)
# Out:
# ['Yes', 'No', 'Yes', 'Yes', 'No', 'No', 'Yes', 'Yes', 'No', 'Yes', 'No']

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d10c461a-6172-4dc9-a3d6-4cef5899ba0d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
